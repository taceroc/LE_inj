# %%
import pandas as pd
import os

import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import astropy.units as u
from astropy.table import Table, vstack
import astropy
from astropy.wcs import WCS
from astropy.coordinates import SkyCoord
from astropy.time import Time
import getpass

import lsst.afw.display as afwDisplay
import lsst.afw.geom as afwGeom
import lsst.afw.image as afwImage
import lsst.afw.math as afwMath
from lsst.daf.butler import Butler
# from lsst.daf.butler.registry import ConflictingDefinitionError
import lsst.geom as geom
# from lsst.source.injection import ingest_injection_catalog, generate_injection_catalog
# from lsst.source.injection import VisitInjectConfig, VisitInjectTask
# from lsst.ip.diffim.subtractImages import AlardLuptonSubtractTask, AlardLuptonSubtractConfig
# from lsst.pipe.tasks.coaddBase import makeSkyInfo

# from lsst.pipe.tasks.characterizeImage import CharacterizeImageTask
# from lsst.pipe.tasks.makeWarp import MakeWarpTask, MakeWarpConfig
# from lsst.meas.algorithms.detection import SourceDetectionTask
# from lsst.meas.deblender import SourceDeblendTask
# from lsst.meas.base import SingleFrameMeasurementTask
# from lsst.meas.base import ForcedMeasurementTask
import lsst.daf.base as dafBase
import lsst.afw.table as afwTable

import lsst.sphgeom as sphgeom

from lsst.ctrl.mpexec import pipeline2dot
from lsst.ctrl.mpexec import SimplePipelineExecutor
from lsst.pipe.base import Pipeline, Instrument

# %% [markdown]
# # Define repo and collections

# %%
repo = '/global/cfs/cdirs/lsst/production/gen3/DC2/Run3.1i/repo'
# These are the collections containing the Y1 processed visit images, etc..
collections = ['u/descdm/sfp_ddf_visits_part_00',
               'u/descdm/sfp_ddf_visits_part_01',
               'u/descdm/sfp_ddf_visits_part_00_visit_tables',
               'u/descdm/sfp_ddf_visits_part_01_visit_tables'
              ]
# collections = ['u/jchiang8/coadds_ddf_y1-y2_4848_assembleCoadd']

# %%
calexp_butler = Butler(repo, collections=collections)

# %% [markdown]
# # Select a calexp to then extract a coordiante for reference

# %%
where = f"instrument='LSSTCam-imSim' AND skymap='DC2' AND \
          band='g'"
calexp_g_DatasetRefs = sorted(list(set(calexp_butler.registry.queryDatasets('calexp', where=where))))
print(f'Identified {len(calexp_g_DatasetRefs)} calexp DatasetRefs')
# Out:
# Identified 7410 calexp DatasetRefs

# %%
dataId = calexp_g_DatasetRefs[5].dataId
print(f"{dataId = }")
# Out:
# dataId = {instrument: 'LSSTCam-imSim', detector: 4, visit: 204414, band: 'g', day_obs: 20221004, physical_filter: 'g_sim_1.4'}

# %%
calexp = calexp_butler.get('calexp', dataId=dataId)
bbox = calexp.getBBox()
wcs = calexp.getWcs()
center = wcs.pixelToSky(bbox.centerX, bbox.centerY)
center
# Out:
# SpherePoint(53.71860108313271*degrees, -28.779074774745983*degrees)

# %%
wcs, bbox
# Out:
# (FITS standard SkyWcs:
#  Sky Origin: (53.7249912323, -28.7927696630)
#  Pixel Origin: (1930.09, 1754.35)
#  Pixel Scale: 0.199783 arcsec/pixel,
#  Box2I(corner=Point2I(0, 0), dimensions=Extent2I(4072, 4000)))

# %%
ra = center.getRa()
dec = center.getDec()

# %%
my_spherePoint = geom.SpherePoint(ra.asDegrees()*geom.degrees, dec.asDegrees()*geom.degrees)

skymap = calexp_butler.get('skyMap', skymap='DC2')
tract = skymap.findTract(my_spherePoint)
my_tract = tract.tract_id
my_patch = tract.findPatch(my_spherePoint).getSequentialIndex()
print('My tract and patch: ', my_tract, my_patch)
# Out:
# My tract and patch:  4849 31

# %% [markdown]
# # Extract dates from all the datasetRefs of calexps

# %%
dates = np.unique([x.dataId['day_obs'] for x in calexp_g_DatasetRefs])

# %%
dates
# Out:
# array([20211231, 20220730, 20220831, 20220902, 20220916, 20220917,
#        20220919, 20221001, 20221004, 20221014, 20221017, 20221020,
#        20221031, 20221103, 20221112, 20221115, 20221118, 20221129,
#        20221202, 20221210, 20221213, 20221216, 20221218, 20221219])

# %% [markdown]
# Just checking that the tract and patch combination have calexps

# %%
for data_id in calexp_butler.registry.queryDataIds(
    ["tract", "visit", "detector", "patch"],
    instrument="LSSTCam-imSim",
    datasets="calexp",
    collections=collections, where=f"skymap='DC2' AND band='g' AND tract=4849 AND patch=31"# AND detector=132 AND visit=250"#AND day_obs=20220101"
).limit(100):
    print(data_id.full)
# Out:
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 115, tract: 4849, patch: 31, visit: 242014, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 115, tract: 4849, patch: 31, visit: 242014, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 250887, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 250887, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225478, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225478, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 119, tract: 4849, patch: 31, visit: 254, band: 'g', day_obs: 20211231, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 7, tract: 4849, patch: 31, visit: 211975, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 73, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 73, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 74, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 74, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254943, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 249466, band: 'g', day_obs: 20221210, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 249466, band: 'g', day_obs: 20221210, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192916, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192916, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 24, tract: 4849, patch: 31, visit: 192916, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 67, tract: 4849, patch: 31, visit: 250889, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 67, tract: 4849, patch: 31, visit: 250889, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 24, tract: 4849, patch: 31, visit: 192916, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 70, tract: 4849, patch: 31, visit: 250889, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 70, tract: 4849, patch: 31, visit: 250889, band: 'g', day_obs: 20221213, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 149, tract: 4849, patch: 31, visit: 225480, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 152, tract: 4849, patch: 31, visit: 225480, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 152, tract: 4849, patch: 31, visit: 225480, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225480, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225480, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 4, tract: 4849, patch: 31, visit: 211977, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 229226, band: 'g', day_obs: 20221112, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 229226, band: 'g', day_obs: 20221112, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 4, tract: 4849, patch: 31, visit: 211977, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 5, tract: 4849, patch: 31, visit: 211977, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 5, tract: 4849, patch: 31, visit: 211977, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 4, tract: 4849, patch: 31, visit: 211974, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 4, tract: 4849, patch: 31, visit: 211974, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 5, tract: 4849, patch: 31, visit: 211974, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 5, tract: 4849, patch: 31, visit: 211974, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 216770, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 216770, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 249468, band: 'g', day_obs: 20221210, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 249468, band: 'g', day_obs: 20221210, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 174, tract: 4849, patch: 31, visit: 242005, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 174, tract: 4849, patch: 31, visit: 242005, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 175, tract: 4849, patch: 31, visit: 242005, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 175, tract: 4849, patch: 31, visit: 242005, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192918, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192918, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192918, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192918, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225482, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225482, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 159, tract: 4849, patch: 31, visit: 225482, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 159, tract: 4849, patch: 31, visit: 225482, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 28, tract: 4849, patch: 31, visit: 159496, band: 'g', day_obs: 20220730, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 108, tract: 4849, patch: 31, visit: 229228, band: 'g', day_obs: 20221112, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 7, tract: 4849, patch: 31, visit: 211979, band: 'g', day_obs: 20221014, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 28, tract: 4849, patch: 31, visit: 159496, band: 'g', day_obs: 20220730, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 216772, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 216772, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 112, tract: 4849, patch: 31, visit: 216772, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 112, tract: 4849, patch: 31, visit: 216772, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 73, tract: 4849, patch: 31, visit: 254934, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 73, tract: 4849, patch: 31, visit: 254934, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254934, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254934, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 25, tract: 4849, patch: 31, visit: 202464, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 25, tract: 4849, patch: 31, visit: 202464, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 115, tract: 4849, patch: 31, visit: 242007, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 115, tract: 4849, patch: 31, visit: 242007, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 154, tract: 4849, patch: 31, visit: 242007, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 154, tract: 4849, patch: 31, visit: 242007, band: 'g', day_obs: 20221129, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192920, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192920, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192920, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192920, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 149, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 149, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 152, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 152, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 156, tract: 4849, patch: 31, visit: 225484, band: 'g', day_obs: 20221031, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 63, tract: 4849, patch: 31, visit: 233539, band: 'g', day_obs: 20221118, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 63, tract: 4849, patch: 31, visit: 233539, band: 'g', day_obs: 20221118, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 229230, band: 'g', day_obs: 20221112, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 109, tract: 4849, patch: 31, visit: 229230, band: 'g', day_obs: 20221112, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 108, tract: 4849, patch: 31, visit: 216774, band: 'g', day_obs: 20221020, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 66, tract: 4849, patch: 31, visit: 227741, band: 'g', day_obs: 20221103, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 69, tract: 4849, patch: 31, visit: 227741, band: 'g', day_obs: 20221103, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254936, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 254936, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 77, tract: 4849, patch: 31, visit: 254936, band: 'g', day_obs: 20221219, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 25, tract: 4849, patch: 31, visit: 202466, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 25, tract: 4849, patch: 31, visit: 202466, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 26, tract: 4849, patch: 31, visit: 202466, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 26, tract: 4849, patch: 31, visit: 202466, band: 'g', day_obs: 20221001, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192922, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 14, tract: 4849, patch: 31, visit: 192922, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 21, tract: 4849, patch: 31, visit: 192922, band: 'g', day_obs: 20220916, physical_filter: 'g_sim_1.4'}
# /tmp/ipykernel_302409/2616655568.py:7: FutureWarning: Call to deprecated function (or staticmethod) full. (DataCoordinate.full is deprecated in favor of .mapping, and will be dropped after v27.) -- Deprecated since version v27.
#   print(data_id.full)

# %% [markdown]
# Extract dates for the tract and patch, just to see they are the same as the step above

# %%
day_obds = [x['day_obs'] for x in list(calexp_butler.registry.queryDataIds(
    ["tract", "visit", "detector", "patch"],
    instrument="LSSTCam-imSim",
    datasets="calexp",
    collections=collections, where=f"skymap='DC2' AND band='g' AND tract=4849 AND patch=31"# AND detector=132 AND visit=250"#AND day_obs=20220101"
))]

# %%
np.unique(day_obds)
# Out:
# array([20211231, 20220730, 20220831, 20220902, 20220916, 20220917,
#        20220919, 20221001, 20221004, 20221014, 20221017, 20221020,
#        20221031, 20221103, 20221112, 20221115, 20221118, 20221129,
#        20221202, 20221210, 20221213, 20221216, 20221218, 20221219])

# %%
np.unique(day_obds) == dates
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %% [markdown]
# # Extract visit tables

# %%
visitTableRef = list(calexp_butler.registry.queryDatasets('visitTable'))

# %%
visitTable = pd.DataFrame()
for v in visitTableRef:
    visitTable_uni = calexp_butler.get(v)
    visitTable_uni = visitTable_uni[visitTable_uni['band'] == 'g']
    visitTable = pd.concat([visitTable,visitTable_uni])

# %%
visitTable
# Out:
#           visit physical_filter band         ra       decl  skyRotation  \
# visitId
# 250         250       g_sim_1.4    g  52.943426 -27.504549   112.222253
# 251         251       g_sim_1.4    g  53.056448 -27.474710    84.536413
# 252         252       g_sim_1.4    g  53.070371 -27.537180    84.414365
# 253         253       g_sim_1.4    g  53.001404 -27.372560    84.731444
# 254         254       g_sim_1.4    g  53.001653 -27.458387    84.566903
# ...         ...             ...  ...        ...        ...          ...
# 254939   254939       g_sim_1.4    g  53.086701 -27.514895    59.936891
# 254940   254940       g_sim_1.4    g  53.049559 -27.353720    58.963644
# 254941   254941       g_sim_1.4    g  52.953957 -27.373719    58.936572
# 254942   254942       g_sim_1.4    g  53.053184 -27.368885    59.081405
# 254943   254943       g_sim_1.4    g  53.096709 -27.478659    59.832271
#
#             azimuth   altitude  zenithDistance   airmass  \
# visitId
# 250      268.049586  62.908761       27.091239  1.113911
# 251      268.096550  62.869524       27.130476  1.114277
# 252      267.902653  62.765900       27.234100  1.115245
# 253      268.153524  62.538675       27.461325  1.117386
# 254      267.905714  62.428878       27.571122  1.118430
# ...             ...        ...             ...       ...
# 254939    74.287582  81.201104        8.798896  1.012526
# 254940    72.907057  81.298642        8.701358  1.012258
# 254941    72.489014  81.509067        8.490933  1.011692
# 254942    72.342836  81.549508        8.450492  1.011584
# 254943    72.800865  81.678150        8.321850  1.011247
#
#                           obsStart  expTime
# visitId
# 250     2022-01-01 03:35:25.545800     30.0
# 251     2022-01-01 03:36:01.574200     30.0
# 252     2022-01-01 03:36:37.603100     30.0
# 253     2022-01-01 03:37:13.545800     30.0
# 254     2022-01-01 03:37:49.574200     30.0
# ...                            ...      ...
# 254939  2022-12-20 01:42:50.880000     30.0
# 254940  2022-12-20 01:43:26.822200     30.0
# 254941  2022-12-20 01:44:02.851100     30.0
# 254942  2022-12-20 01:44:38.880000     30.0
# 254943  2022-12-20 01:45:14.822200     30.0
#
# [212 rows x 12 columns]

# %% [markdown]
# ## Convert visit dates to julian date

# %%
visitTable.loc[:, 'jd'] = visitTable.loc[:, 'obsStart'].map(lambda x: x.to_julian_date())
visitTable.loc[:, 'jd'] = visitTable.loc[:, 'jd'].map(lambda x: round(x,0))

# %% [markdown]
# ## Convert calexps dates to julian date

# %%
dates_calexps = pd.DataFrame()
dates_calexps.loc[:, 'year'] = [str(x)[:4] for x in day_obds]
dates_calexps.loc[:, 'month'] = [str(x)[4:6] for x in day_obds]
dates_calexps.loc[:, 'day'] = [str(x)[6:] for x in day_obds]
dates_calexps.loc[:, 'time'] = dates_calexps.loc[:, 'year']+'-'+dates_calexps.loc[:, 'month']+'-'+dates_calexps.loc[:, 'day']
dates_calexps.loc[:, 'time'] = dates_calexps.loc[:, 'time'].map(lambda x: Time(x))
dates_calexps.loc[:, 'jd'] = dates_calexps.loc[:, 'time'].map(lambda x: x.jd)
dates_calexps.loc[:, 'jd'] = dates_calexps.loc[:, 'jd'].map(lambda x: round(x,0))

# %%
dates_calexps.groupby('jd').size()
# Out:
# jd
# 2459580.0    29
# 2459790.0     2
# 2459822.0     2
# 2459824.0    37
# 2459838.0    32
# 2459840.0     2
# 2459842.0    39
# 2459854.0    32
# 2459856.0    28
# 2459866.0    25
# 2459870.0    34
# 2459872.0    29
# 2459884.0    39
# 2459886.0    21
# 2459896.0    26
# 2459898.0    24
# 2459902.0    22
# 2459912.0    31
# 2459916.0    37
# 2459924.0    20
# 2459926.0    30
# 2459930.0    26
# 2459932.0    42
# dtype: int64

# %%
dates_calexps.groupby('jd').agg({'time': 'first'})
# Out:
#                               time
# jd
# 2459580.0  2021-12-31 00:00:00.000
# 2459790.0  2022-07-30 00:00:00.000
# 2459822.0  2022-08-31 00:00:00.000
# 2459824.0  2022-09-02 00:00:00.000
# 2459838.0  2022-09-16 00:00:00.000
# 2459840.0  2022-09-17 00:00:00.000
# 2459842.0  2022-09-19 00:00:00.000
# 2459854.0  2022-10-01 00:00:00.000
# 2459856.0  2022-10-04 00:00:00.000
# 2459866.0  2022-10-14 00:00:00.000
# 2459870.0  2022-10-17 00:00:00.000
# 2459872.0  2022-10-20 00:00:00.000
# 2459884.0  2022-10-31 00:00:00.000
# 2459886.0  2022-11-03 00:00:00.000
# 2459896.0  2022-11-12 00:00:00.000
# 2459898.0  2022-11-15 00:00:00.000
# 2459902.0  2022-11-18 00:00:00.000
# 2459912.0  2022-11-29 00:00:00.000
# 2459916.0  2022-12-02 00:00:00.000
# 2459924.0  2022-12-10 00:00:00.000
# 2459926.0  2022-12-13 00:00:00.000
# 2459930.0  2022-12-16 00:00:00.000
# 2459932.0  2022-12-19 00:00:00.000

# %% [markdown]
# # Select the visits that fall within the 1st and 2nd time of the calexps

# %%
my_range = np.array((visitTable['jd'] >= np.unique(dates_calexps['jd'])[3]) & 
                    (visitTable['jd'] < np.unique(dates_calexps['jd'])[4]))


# my_range2 = np.array((visitTable['jd'] > np.unique(dates_calexps['jd'])[2]) & 
#                     (visitTable['jd'] <= np.unique(dates_calexps['jd'])[3]))

# %%
# my_range2 + my_range

# %%
my_visits = visitTable.visit[my_range]
my_visits_tupleString = "("+",".join(my_visits.astype(str))+")"
print(my_visits_tupleString)
# Out:
# (183767,183768,183809,183811,183812,185615,185616,185617,185618,185619,185620,185621,185622,185623,185624,185735,185736,185783,185785)

# %% [markdown]
# Just checking there're calexp for the tract, patch and visits

# %%
for data_id in calexp_butler.registry.queryDataIds(
    ["tract", "visit", "detector", "patch"],
    instrument="LSSTCam-imSim",
    datasets="calexp",
    collections=collections, where=f"skymap='DC2' AND band='g' AND tract=4849 AND patch=31 AND visit in {my_visits_tupleString}"#AND day_obs=20211231"# AND detector=132 AND visit=250"#AND day_obs=20220101"
).limit(100):
    print(data_id.full)
# Out:
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 86, tract: 4849, patch: 31, visit: 183811, band: 'g', day_obs: 20220831, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 86, tract: 4849, patch: 31, visit: 183811, band: 'g', day_obs: 20220831, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 185615, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 76, tract: 4849, patch: 31, visit: 185615, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185616, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185616, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 119, tract: 4849, patch: 31, visit: 185617, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 119, tract: 4849, patch: 31, visit: 185617, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185617, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185617, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185618, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185618, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 119, tract: 4849, patch: 31, visit: 185619, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 119, tract: 4849, patch: 31, visit: 185619, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185619, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185619, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185620, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185620, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185621, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 118, tract: 4849, patch: 31, visit: 185622, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 118, tract: 4849, patch: 31, visit: 185622, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 121, tract: 4849, patch: 31, visit: 185622, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 121, tract: 4849, patch: 31, visit: 185622, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185623, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185623, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185624, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 122, tract: 4849, patch: 31, visit: 185624, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 178, tract: 4849, patch: 31, visit: 185735, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 178, tract: 4849, patch: 31, visit: 185735, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 164, tract: 4849, patch: 31, visit: 185736, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 164, tract: 4849, patch: 31, visit: 185736, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 139, tract: 4849, patch: 31, visit: 185783, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 139, tract: 4849, patch: 31, visit: 185783, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 142, tract: 4849, patch: 31, visit: 185783, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 142, tract: 4849, patch: 31, visit: 185783, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 67, tract: 4849, patch: 31, visit: 185785, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 67, tract: 4849, patch: 31, visit: 185785, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 70, tract: 4849, patch: 31, visit: 185785, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# {instrument: 'LSSTCam-imSim', skymap: 'DC2', detector: 70, tract: 4849, patch: 31, visit: 185785, band: 'g', day_obs: 20220902, physical_filter: 'g_sim_1.4'}
# /tmp/ipykernel_302409/3020545707.py:7: FutureWarning: Call to deprecated function (or staticmethod) full. (DataCoordinate.full is deprecated in favor of .mapping, and will be dropped after v27.) -- Deprecated since version v27.
#   print(data_id.full)

# %%
visitTable[my_range]
# Out:
#           visit physical_filter band         ra       decl  skyRotation  \
# visitId
# 183767   183767       g_sim_1.4    g  51.682527 -28.027720   338.015794
# 183768   183768       g_sim_1.4    g  51.686828 -29.590692   340.290324
# 183809   183809       g_sim_1.4    g  52.755108 -25.821604   333.130080
# 183811   183811       g_sim_1.4    g  53.244325 -28.918670   338.517372
# 183812   183812       g_sim_1.4    g  51.689473 -29.908798   340.679684
# 185615   185615       g_sim_1.4    g  53.034002 -27.393355    65.237403
# 185616   185616       g_sim_1.4    g  52.934748 -27.438014    89.693447
# 185617   185617       g_sim_1.4    g  53.074379 -27.443361    89.674838
# 185618   185618       g_sim_1.4    g  52.886790 -27.444196    89.708627
# 185619   185619       g_sim_1.4    g  53.080475 -27.452161    89.683810
# 185620   185620       g_sim_1.4    g  52.979957 -27.521245    89.782033
# 185621   185621       g_sim_1.4    g  52.903785 -27.405982    89.660079
# 185622   185622       g_sim_1.4    g  53.061163 -27.357647    89.576036
# 185623   185623       g_sim_1.4    g  52.989481 -27.458460    89.706812
# 185624   185624       g_sim_1.4    g  52.907559 -27.483721    89.750898
# 185735   185735       g_sim_1.4    g  51.743243 -29.081963    74.681400
# 185736   185736       g_sim_1.4    g  52.326239 -28.623367    73.405083
# 185783   185783       g_sim_1.4    g  54.451923 -29.195523   310.523162
# 185785   185785       g_sim_1.4    g  54.027096 -27.119296   302.256507
#
#            azimuth   altitude  zenithDistance   airmass  \
# visitId
# 183767   96.132669  56.199235       33.800765  1.198199
# 183768   98.843617  56.663183       33.336817  1.191937
# 183809   89.385309  60.892021       29.107979  1.141959
# 183811   95.704938  61.478329       28.521671  1.135613
# 183812   97.258178  63.121202       26.878798  1.119182
# 185615   97.623811  50.140114       39.859886  1.292209
# 185616   97.599873  50.365465       39.634535  1.288211
# 185617   97.603975  50.376204       39.623796  1.288018
# 185618   97.481481  50.665991       39.334009  1.282947
# 185619   97.509543  50.630805       39.369195  1.283555
# 185620   97.523219  50.863823       39.136177  1.279514
# 185621   97.263459  51.028028       38.971972  1.276707
# 185622   97.191964  51.009203       38.990797  1.277030
# 185623   97.265032  51.225940       38.774060  1.273333
# 185624   97.218625  51.431690       38.568310  1.269864
# 185735   92.390914  70.173780       19.826220  1.062862
# 185736   91.249505  69.738730       20.261270  1.065753
# 185783   89.756978  75.975616       14.024384  1.031187
# 185785   80.713383  76.187530       13.812470  1.030301
#
#                           obsStart  expTime         jd
# visitId
# 183767  2022-09-01 06:53:05.587100     30.0  2459824.0
# 183768  2022-09-01 06:53:44.208000     30.0  2459824.0
# 183809  2022-09-01 07:21:40.108900     30.0  2459824.0
# 183811  2022-09-01 07:22:57.609800     30.0  2459824.0
# 183812  2022-09-01 07:23:36.662200     30.0  2459824.0
# 185615  2022-09-03 06:23:10.195100     30.0  2459826.0
# 185616  2022-09-03 06:23:46.137800     30.0  2459826.0
# 185617  2022-09-03 06:24:22.166200     30.0  2459826.0
# 185618  2022-09-03 06:24:58.195100     30.0  2459826.0
# 185619  2022-09-03 06:25:34.137800     30.0  2459826.0
# 185620  2022-09-03 06:26:10.166200     30.0  2459826.0
# 185621  2022-09-03 06:26:46.195100     30.0  2459826.0
# 185622  2022-09-03 06:27:22.137800     30.0  2459826.0
# 185623  2022-09-03 06:27:58.166199     30.0  2459826.0
# 185624  2022-09-03 06:28:34.195100     30.0  2459826.0
# 185735  2022-09-03 07:49:14.323100     30.0  2459826.0
# 185736  2022-09-03 07:49:54.585800     30.0  2459826.0
# 185783  2022-09-03 08:26:45.820900     30.0  2459826.0
# 185785  2022-09-03 08:28:07.641800     30.0  2459826.0

# %% [markdown]
# # Create the butler for the ouputs of the pipeline

# %%
my_collection_identifier = 'custom_coadd_test_2_442025'
print(my_collection_identifier)
# Out:
# custom_coadd_test_2_442025

# %%
user = os.getenv("USER")
print(user)
# Out:
# taceroc

# %%
my_outputCollection = f"u/{user}/{my_collection_identifier}"
print('Name of new butler collection for my output: ', my_outputCollection)
# Out:
# Name of new butler collection for my output:  u/taceroc/custom_coadd_test_2_442025

# %% [markdown]
# # Define the bulter

# %%
simpleButler = SimplePipelineExecutor.prep_butler(repo, 
                                                  inputs=collections, 
                                                  output=my_outputCollection)

# %%
simpleButler.registry.getCollectionChain(my_outputCollection)
# Out:
# ('u/taceroc/custom_coadd_test_2_442025/20250404T182024Z',
#  'u/descdm/sfp_ddf_visits_part_00',
#  'u/descdm/sfp_ddf_visits_part_01',
#  'u/descdm/sfp_ddf_visits_part_00_visit_tables',
#  'u/descdm/sfp_ddf_visits_part_01_visit_tables')

# %%
! echo $DRP_PIPE_DIR
# Out:
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/drp_pipe/gfa69e0f95e+cb6a7025ff

# %% [markdown]
# ## Run like this for now, no whole step3

# %%
yaml_file = '$DRP_PIPE_DIR/pipelines/LSSTCam-imSim/DRP-test-med-1.yaml'
steps = 'step1,step2,makeWarp,selectDeepCoaddVisits,assembleCoadd,detection,mergeDetections,deblend,measure'
# steps = 'step1,step2,step3'
my_uri = yaml_file + '#' + steps
print(my_uri)
# Out:
# $DRP_PIPE_DIR/pipelines/LSSTCam-imSim/DRP-test-med-1.yaml#step1,step2,makeWarp,selectDeepCoaddVisits,assembleCoadd,detection,mergeDetections,deblend,measure

# %%
assembleCoaddPipeline = Pipeline.from_uri(my_uri)

# %% [markdown]
# leave all as the default, then maybe change it

# %%
# assembleCoaddPipeline.addConfigOverride('makeWarp', 
#                                         'connections.visitSummary', 
#                                         "visitSummary")
# assembleCoaddPipeline.addConfigOverride('makeWarp', 
#                                         'doWriteEmptyWarps', 
#                                         True)
# assembleCoaddPipeline.addConfigOverride('makeWarp', 
#                                         'useVisitSummaryPsf', 
#                                         False)
# assembleCoaddPipeline.addConfigOverride('assembleCoadd', 'doSelectVisits', False)

# %%
# pipeline2dot(assembleCoaddPipeline, "/global/homes/t/taceroc/custom_coadd_qgraph.dot")

# ! dot -Tpng "/global/homes/t/taceroc/custom_coadd_qgraph.dot" > "/global/homes/t/taceroc/custom_coadd_qgraph.png"
# Out:
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/obs_lsst/g5c5439fafc+141fc35c6f/config/assembleCoadd.py:28: FutureWarning: Config field doSigmaClip is deprecated: True
#   config.doSigmaClip = False

# %% [markdown]
# # Define query for tract, patch and visits

# %%
queryString = f"tract = {my_tract} AND patch = {my_patch} AND " + \
              f"visit in {my_visits_tupleString} AND skymap = 'DC2'"
print(queryString)
# Out:
# tract = 4849 AND patch = 31 AND visit in (183767,183768,183809,183811,183812,185615,185616,185617,185618,185619,185620,185621,185622,185623,185624,185735,185736,185783,185785) AND skymap = 'DC2'

# %%
spe = SimplePipelineExecutor.from_pipeline(assembleCoaddPipeline, 
                                           where=queryString, 
                                           butler=simpleButler)
# Out:
# /cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/obs_lsst/g5c5439fafc+141fc35c6f/config/assembleCoadd.py:28: FutureWarning: Config field doSigmaClip is deprecated: True
#   config.doSigmaClip = False

# %% [markdown]
# # Run the pipeline

# %%
quanta = spe.run('--register-dataset-types')
# Out:
# Traceback (most recent call last):
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 946, in deblend
#     blend, skippedSources, skippedBands = deblend(
#                                           ^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 137, in deblend
#     observation = buildObservation(
#                   ^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 190, in buildObservation
#     psfModels, mExposure = computePsfKernelImage(mExposure, psfCenter)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 127, in computePsfKernelImage
#     psfModels = mExposure.computePsfKernelImage(psfCenter)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 246, in computePsfKernelImage
#     return computePsfImage(
#            ^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 103, in computePsfImage
#     left = np.min([psf.getBBox().getMinX() for psf in psfs.values()])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 200, in amin
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 2946, in amin
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity
# Traceback (most recent call last):
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 946, in deblend
#     blend, skippedSources, skippedBands = deblend(
#                                           ^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 137, in deblend
#     observation = buildObservation(
#                   ^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 190, in buildObservation
#     psfModels, mExposure = computePsfKernelImage(mExposure, psfCenter)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 127, in computePsfKernelImage
#     psfModels = mExposure.computePsfKernelImage(psfCenter)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 246, in computePsfKernelImage
#     return computePsfImage(
#            ^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 103, in computePsfImage
#     left = np.min([psf.getBBox().getMinX() for psf in psfs.values()])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 200, in amin
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 2946, in amin
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity
# Traceback (most recent call last):
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 946, in deblend
#     blend, skippedSources, skippedBands = deblend(
#                                           ^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/scarletDeblendTask.py", line 137, in deblend
#     observation = buildObservation(
#                   ^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 190, in buildObservation
#     psfModels, mExposure = computePsfKernelImage(mExposure, psfCenter)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/meas_extensions_scarlet/g1850869495+d7bfc87f51/python/lsst/meas/extensions/scarlet/utils.py", line 127, in computePsfKernelImage
#     psfModels = mExposure.computePsfKernelImage(psfCenter)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 246, in computePsfKernelImage
#     return computePsfImage(
#            ^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/share/eups/Linux64/afw/g5a732f18d5+be83d3ecdb/python/lsst/afw/image/_exposure/_multiband.py", line 103, in computePsfImage
#     left = np.min([psf.getBBox().getMinX() for psf in psfs.values()])
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<__array_function__ internals>", line 200, in amin
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 2946, in amin
#     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/cvmfs/sw.lsst.eu/linux-x86_64/lsst_distrib/v27.0.0/conda/envs/lsst-scipipe-8.0.0-exact-ext/lib/python3.11/site-packages/numpy/core/fromnumeric.py", line 86, in _wrapreduction
#     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: zero-size array to reduction operation minimum which has no identity

# %% [markdown]
# check that all seems fine

# %%
for q, quantum in enumerate(quanta):
    print(q, quantum.taskName)
# Out:
# 0 lsst.ip.isr.isrTask.IsrTask
# 1 lsst.ip.isr.isrTask.IsrTask
# 2 lsst.ip.isr.isrTask.IsrTask
# 3 lsst.ip.isr.isrTask.IsrTask
# 4 lsst.ip.isr.isrTask.IsrTask
# 5 lsst.ip.isr.isrTask.IsrTask
# 6 lsst.ip.isr.isrTask.IsrTask
# 7 lsst.ip.isr.isrTask.IsrTask
# 8 lsst.ip.isr.isrTask.IsrTask
# 9 lsst.ip.isr.isrTask.IsrTask
# 10 lsst.ip.isr.isrTask.IsrTask
# 11 lsst.ip.isr.isrTask.IsrTask
# 12 lsst.ip.isr.isrTask.IsrTask
# 13 lsst.ip.isr.isrTask.IsrTask
# 14 lsst.ip.isr.isrTask.IsrTask
# 15 lsst.ip.isr.isrTask.IsrTask
# 16 lsst.ip.isr.isrTask.IsrTask
# 17 lsst.ip.isr.isrTask.IsrTask
# 18 lsst.ip.isr.isrTask.IsrTask
# 19 lsst.ip.isr.isrTask.IsrTask
# 20 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 21 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 22 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 23 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 24 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 25 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 26 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 27 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 28 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 29 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 30 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 31 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 32 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 33 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 34 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 35 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 36 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 37 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 38 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 39 lsst.pipe.tasks.characterizeImage.CharacterizeImageTask
# 40 lsst.pipe.tasks.calibrate.CalibrateTask
# 41 lsst.pipe.tasks.calibrate.CalibrateTask
# 42 lsst.pipe.tasks.calibrate.CalibrateTask
# 43 lsst.pipe.tasks.calibrate.CalibrateTask
# 44 lsst.pipe.tasks.calibrate.CalibrateTask
# 45 lsst.pipe.tasks.calibrate.CalibrateTask
# 46 lsst.pipe.tasks.calibrate.CalibrateTask
# 47 lsst.pipe.tasks.calibrate.CalibrateTask
# 48 lsst.pipe.tasks.calibrate.CalibrateTask
# 49 lsst.pipe.tasks.calibrate.CalibrateTask
# 50 lsst.pipe.tasks.calibrate.CalibrateTask
# 51 lsst.pipe.tasks.calibrate.CalibrateTask
# 52 lsst.pipe.tasks.calibrate.CalibrateTask
# 53 lsst.pipe.tasks.calibrate.CalibrateTask
# 54 lsst.pipe.tasks.calibrate.CalibrateTask
# 55 lsst.pipe.tasks.calibrate.CalibrateTask
# 56 lsst.pipe.tasks.calibrate.CalibrateTask
# 57 lsst.pipe.tasks.calibrate.CalibrateTask
# 58 lsst.pipe.tasks.calibrate.CalibrateTask
# 59 lsst.pipe.tasks.calibrate.CalibrateTask
# 60 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 61 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 62 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 63 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 64 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 65 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 66 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 67 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 68 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 69 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 70 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 71 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 72 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 73 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 74 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 75 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 76 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 77 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 78 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 79 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 80 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 81 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 82 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 83 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 84 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 85 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 86 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 87 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 88 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 89 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 90 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 91 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 92 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 93 lsst.pipe.tasks.postprocess.WriteSourceTableTask
# 94 lsst.pipe.tasks.postprocess.ConsolidateVisitSummaryTask
# 95 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 96 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 97 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 98 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 99 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 100 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 101 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 102 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 103 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 104 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 105 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 106 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 107 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 108 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 109 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 110 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 111 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 112 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 113 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 114 lsst.pipe.tasks.postprocess.TransformSourceTableTask
# 115 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 116 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 117 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 118 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 119 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 120 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 121 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 122 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 123 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 124 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 125 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 126 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 127 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 128 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 129 lsst.pipe.tasks.postprocess.ConsolidateSourceTableTask
# 130 lsst.pipe.tasks.isolatedStarAssociation.IsolatedStarAssociationTask
# 131 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 132 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 133 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 134 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 135 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 136 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 137 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 138 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 139 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 140 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 141 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 142 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 143 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 144 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 145 lsst.pipe.tasks.finalizeCharacterization.FinalizeCharacterizationTask
# 146 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 147 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 148 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 149 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 150 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 151 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 152 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 153 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 154 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 155 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 156 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 157 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 158 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 159 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 160 lsst.drp.tasks.update_visit_summary.UpdateVisitSummaryTask
# 161 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 162 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 163 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 164 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 165 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 166 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 167 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 168 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 169 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 170 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 171 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 172 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 173 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 174 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 175 lsst.pipe.tasks.postprocess.MakeVisitTableTask
# 176 lsst.pipe.tasks.postprocess.MakeCcdVisitTableTask
# 177 lsst.pipe.tasks.selectImages.BestSeeingSelectVisitsTask
# 178 lsst.pipe.tasks.makeWarp.MakeWarpTask
# 179 lsst.drp.tasks.assemble_coadd.CompareWarpAssembleCoaddTask
# 180 lsst.pipe.tasks.multiBand.DetectCoaddSourcesTask
# 181 lsst.pipe.tasks.mergeDetections.MergeDetectionsTask
# 182 lsst.pipe.tasks.deblendCoaddSourcesPipeline.DeblendCoaddSourcesMultiTask
# 183 lsst.pipe.tasks.multiBand.MeasureMergedCoaddSourcesTask

# %% [markdown]
# # Check if the coadd exists

# %%
list(simpleButler.registry.queryDatasets('deepCoadd'))
# Out:
# [DatasetRef(DatasetType('deepCoadd', {band, skymap, tract, patch}, ExposureF), {band: 'g', skymap: 'DC2', tract: 4849, patch: 31}, run='u/taceroc/custom_coadd_test_2_442025/20250404T182024Z', id=63fc527d-54e0-4203-9080-31287c23b4fe)]

# %%
deepCoadd_test = simpleButler.get(list(simpleButler.registry.queryDatasets('deepCoadd'))[0])

# %%
afwDisplay.setDefaultBackend('matplotlib')
plt.style.use('tableau-colorblind10')

# %%
fig, ax = plt.subplots(1, 1, figsize=(5, 5), dpi=150)

display2 = afwDisplay.Display(frame=fig)
display2.scale('linear', 'zscale')
# display2.scale('linear', min=-20, max=150)
display2.mtv(deepCoadd_test.image)
wcs = deepCoadd_test.getWcs()
center = wcs.skyToPixel(geom.SpherePoint(ra, dec))
display2.dot('+', center.x, center.y, size=20, ctype='orange')
# To zoom on the PGC 038749 stamp:
# display2.mtv(result.difference.image[xy[0]+100:xy[0]-100, xy[1]+100:xy[1]-100])#[3510:3560, 1750:1800])
# plt.title(f"warp {my_coadd_visits_mjds['mjd'].unique()[0]} to {my_coadd_visits_mjds['mjd'].unique()[1]}")

plt.tight_layout()
plt.show()

# %%
list(simpleButler.registry.queryDatasets('deepCoadd_meas'))
# Out:
# [DatasetRef(DatasetType('deepCoadd_meas', {band, skymap, tract, patch}, SourceCatalog), {band: 'g', skymap: 'DC2', tract: 4849, patch: 31}, run='u/taceroc/custom_coadd_test_2_442025/20250404T182024Z', id=fb47e7e5-aca5-4c03-badb-9ab31a478fc2)]

# %%
deepCoadd_src = simpleButler.get(list(simpleButler.registry.queryDatasets('deepCoadd_meas'))[0])

# %%
len(deepCoadd_src.asAstropy())
# Out:
# 12305

# %%
deepCoadd_src.asAstropy()
# Out:
# <Table length=12305>
#          id              coord_ra      ... base_FootprintArea_value
#                            rad         ...           pix
#        int64             float64       ...          int32
# ------------------- ------------------ ... ------------------------
# 2090233177053331457 0.9398850456434685 ...                      181
# 2090233177053331458 0.9398739608953769 ...                      177
# 2090233177053331459 0.9399110466124846 ...                      121
# 2090233177053331460 0.9398716371583378 ...                       92
# 2090233177053331461 0.9396640355055288 ...                      152
# 2090233177053331462 0.9399246677647194 ...                       92
# 2090233177053331463 0.9396829245974908 ...                      128
# 2090233177053331464 0.9398094250186053 ...                       81
# 2090233177053331465 0.9399418069928714 ...                      151
#                 ...                ... ...                      ...
# 2090233177053348964 0.9391564851111013 ...                      268
# 2090233177053348965 0.9407990457532269 ...                     1016
# 2090233177053348966 0.9408181138412134 ...                      393
# 2090233177053348967 0.9407352317366263 ...                      154
# 2090233177053348968 0.9407473890719136 ...                      164
# 2090233177053348969 0.9374950913787822 ...                      125
# 2090233177053348970  0.937360271315834 ...                      347
# 2090233177053348971 0.9373422116476443 ...                      494
# 2090233177053348972  0.937331529472067 ...                      321

# %%
deepCoadd_src.asAstropy().to_pandas().columns
# Out:
# Index(['id', 'coord_ra', 'coord_dec', 'parent', 'merge_footprint_i',
#        'merge_footprint_r', 'merge_footprint_z', 'merge_footprint_y',
#        'merge_footprint_g', 'merge_footprint_u',
#        ...
#        'slot_ModelFlux_exp_flag_apCorr', 'modelfit_CModel_initial_apCorr',
#        'slot_ModelFlux_initial_apCorr', 'modelfit_CModel_initial_apCorrErr',
#        'slot_ModelFlux_initial_apCorrErr',
#        'modelfit_CModel_initial_flag_apCorr',
#        'slot_ModelFlux_initial_flag_apCorr',
#        'base_ClassificationExtendedness_value',
#        'base_ClassificationExtendedness_flag', 'base_FootprintArea_value'],
#       dtype='object', length=948)

# %%
deepCoadd_src.asAstropy().to_pandas()[deepCoadd_src.asAstropy().to_pandas()['deblend_runtime'] > 0]
# Out:
#                        id  coord_ra  coord_dec  parent  merge_footprint_i  \
# 0     2090233177053331457  0.939885  -0.504270       0              False
# 1     2090233177053331458  0.939874  -0.504216       0              False
# 2     2090233177053331459  0.939911  -0.504211       0              False
# 3     2090233177053331460  0.939872  -0.504145       0              False
# 4     2090233177053331461  0.939664  -0.504128       0              False
# ...                   ...       ...        ...     ...                ...
# 5106  2090233177053336563  0.939162  -0.500383       0              False
# 5107  2090233177053336564  0.940799  -0.500399       0              False
# 5108  2090233177053336565  0.940735  -0.500383       0              False
# 5109  2090233177053336566  0.937495  -0.500383       0              False
# 5110  2090233177053336567  0.937360  -0.500382       0              False
#
#       merge_footprint_r  merge_footprint_z  merge_footprint_y  \
# 0                 False              False              False
# 1                 False              False              False
# 2                 False              False              False
# 3                 False              False              False
# 4                 False              False              False
# ...                 ...                ...                ...
# 5106              False              False              False
# 5107              False              False              False
# 5108              False              False              False
# 5109              False              False              False
# 5110              False              False              False
#
#       merge_footprint_g  merge_footprint_u  ...  \
# 0                  True              False  ...
# 1                  True              False  ...
# 2                  True              False  ...
# 3                  True              False  ...
# 4                  True              False  ...
# ...                 ...                ...  ...
# 5106               True              False  ...
# 5107               True              False  ...
# 5108               True              False  ...
# 5109               True              False  ...
# 5110               True              False  ...
#
#       slot_ModelFlux_exp_flag_apCorr  modelfit_CModel_initial_apCorr  \
# 0                              False                        1.002725
# 1                              False                        1.002184
# 2                              False                        1.001939
# 3                              False                        1.001432
# 4                              False                        1.002293
# ...                              ...                             ...
# 5106                           False                        0.991338
# 5107                           False                        0.994195
# 5108                           False                        0.994132
# 5109                           False                        0.987530
# 5110                           False                        0.987106
#
#       slot_ModelFlux_initial_apCorr  modelfit_CModel_initial_apCorrErr  \
# 0                          1.002725                                0.0
# 1                          1.002184                                0.0
# 2                          1.001939                                0.0
# 3                          1.001432                                0.0
# 4                          1.002293                                0.0
# ...                             ...                                ...
# 5106                       0.991338                                0.0
# 5107                       0.994195                                0.0
# 5108                       0.994132                                0.0
# 5109                       0.987530                                0.0
# 5110                       0.987106                                0.0
#
#       slot_ModelFlux_initial_apCorrErr  modelfit_CModel_initial_flag_apCorr  \
# 0                                  0.0                                False
# 1                                  0.0                                False
# 2                                  0.0                                False
# 3                                  0.0                                False
# 4                                  0.0                                False
# ...                                ...                                  ...
# 5106                               0.0                                False
# 5107                               0.0                                False
# 5108                               0.0                                False
# 5109                               0.0                                False
# 5110                               0.0                                False
#
#       slot_ModelFlux_initial_flag_apCorr  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 5106                               False
# 5107                               False
# 5108                               False
# 5109                               False
# 5110                               False
#
#       base_ClassificationExtendedness_value  \
# 0                                       NaN
# 1                                       NaN
# 2                                       1.0
# 3                                       0.0
# 4                                       NaN
# ...                                     ...
# 5106                                    NaN
# 5107                                    NaN
# 5108                                    NaN
# 5109                                    NaN
# 5110                                    NaN
#
#       base_ClassificationExtendedness_flag  base_FootprintArea_value
# 0                                     True                       181
# 1                                     True                       177
# 2                                    False                       121
# 3                                    False                        92
# 4                                     True                       152
# ...                                    ...                       ...
# 5106                                  True                       316
# 5107                                  True                      1082
# 5108                                  True                       196
# 5109                                  True                       125
# 5110                                  True                       640
#
# [5108 rows x 948 columns]
