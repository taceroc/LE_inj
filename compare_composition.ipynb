# %%
import sys
sys.path.append("lightecho_modeling_oop/OOP")
import SimulateLEInfPlane
from definitions import CONFIG_PATH_UTILS, CONFIG_PATH_DUST
sys.path.append(CONFIG_PATH_UTILS)

sys.path.append(CONFIG_PATH_DUST)
import var_constants as vc
import fix_constants as fc
import dust_constants as dc
from Source import Source
import numpy as np
import yaml

import matplotlib.pyplot as plt

# %%
# from LE_img import LEImageAnalytical

# %%
# from scipy.interpolate import griddata

# %%
sim_le = SimulateLEInfPlane.CalculateLE(file_name='/pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml', 
                                ids=0, args=[False, False])
# Out:
# [False, False] /pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml 0
# {'Flmax': 1e+16, 'angles': [0, 360], 'ct': 640, 'd': 52000, 'dt0': 0, 'dz0': 0.06, 'plane_coefficients': [0, 0, 1, 120], 'wave': 0.567, 'loc_to_fits': '4026_15_v2/plane', 'composition': 'both'}
# /pscratch/sd/t/taceroc/LE_inj
# True
# TIME LE elliposid in days 656.8679000000047
# TIME of the SN LC respect to peak -16.867900000004738
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# mean of rho 37.575941362184594
# half_obs_thickness given by dust 0.004686218799740174
# carb values
# silicate values
# FLUX AFTER SURFACE 1.1901653198111636e-38
# size arcsec 91.0 91.0
# size img pixels 455 455
# OBS TIME 640.0

# %%
surface_val = sim_le.run()
# Out:
# True
# TIME LE elliposid in days 624.0312000000049
# TIME of the SN LC respect to peak 15.968799999995097
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 5.671489571383294e-16
# mean of rho 36.62259388655853
# half_obs_thickness given by dust 0.004567847486726299
# carb values
# silicate values
# FLUX AFTER SURFACE 3.186884319063471e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 605.0108000000037
# TIME of the SN LC respect to peak 34.989199999996345
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.116837363414515e-16
# mean of rho 36.05895095667916
# half_obs_thickness given by dust 0.004497844445814733
# carb values
# silicate values
# FLUX AFTER SURFACE 3.4374147568227485e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 594.7243000000017
# TIME of the SN LC respect to peak 45.27569999999833
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.358218490763986e-16
# mean of rho 35.75045426634921
# half_obs_thickness given by dust 0.004459524061245355
# carb values
# silicate values
# FLUX AFTER SURFACE 3.573220661655559e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 584.3940000000002
# TIME of the SN LC respect to peak 55.60599999999977
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.449795327198281e-16
# mean of rho 35.43796393053855
# half_obs_thickness given by dust 0.004420703412704805
# carb values
# silicate values
# FLUX AFTER SURFACE 3.624847922999559e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 562.5959000000003
# TIME of the SN LC respect to peak 77.40409999999974
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.694127562418332e-16
# mean of rho 34.769435136109095
# half_obs_thickness given by dust 0.004337638149873868
# carb values
# silicate values
# FLUX AFTER SURFACE 3.762520942036941e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 521.5740000000005
# TIME of the SN LC respect to peak 118.42599999999946
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.029788998199897e-16
# mean of rho 33.4754329298845
# half_obs_thickness given by dust 0.004176804267905176
# carb values
# silicate values
# FLUX AFTER SURFACE 3.9518873795698554e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 478.3228999999992
# TIME of the SN LC respect to peak 161.6771000000008
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.240944873261619e-16
# mean of rho 32.05501671928607
# half_obs_thickness given by dust 0.004000180219690203
# carb values
# silicate values
# FLUX AFTER SURFACE 4.0713557972260215e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 443.86409999999876
# TIME of the SN LC respect to peak 196.13590000000116
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.331408270166057e-16
# mean of rho 30.876942142812602
# half_obs_thickness given by dust 0.003853631015404064
# carb values
# silicate values
# FLUX AFTER SURFACE 4.122837351563939e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 384.6546999999991
# TIME of the SN LC respect to peak 255.34530000000086
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.412385256498134e-16
# mean of rho 28.740866687111744
# half_obs_thickness given by dust 0.003587778106344488
# carb values
# silicate values
# FLUX AFTER SURFACE 4.169447014080799e-30
# Before angle clipping
# Len of z values
# 0
# Total shape
# (1, 2, 9000)
# FLUX 3.7667129050021e-30
# mean surface 24.75159505892899
# [-16.867900000004738, 15.968799999995097, 34.989199999996345, 45.27569999999833, 55.60599999999977, 77.40409999999974, 118.42599999999946, 161.6771000000008, 196.13590000000116, 255.34530000000086]
# [656.8679000000047, 624.0312000000049, 605.0108000000037, 594.7243000000017, 584.3940000000002, 562.5959000000003, 521.5740000000005, 478.3228999999992, 443.86409999999876, 384.6546999999991]
# (9000,)
# ANGLES
# 0 360
# 36.62259388655852 -36.62241279945744
# 36.62254861475527 -36.62254861475527
# (455, 455)
# (455, 455) (455, 455) nan nan

# %%
plt.imshow(-2.5*np.log10(surface_val)-48.6, origin='lower', cmap='Greys_r')
plt.colorbar()

# %%
# x_inter_values_t0, y_inter_values_t0, z_inter_values_t0, new_xs_t0, new_ys_t0, new_zs_t0, LE_plane1source1_tt1 = initi_LE.calculate_xyz_x_specific_phase_lc_time(initi_LE.lc['time'][::40][0],
#                                                                                                                                           return_LE_plane1source1=True)

# %%
plt.scatter(sim_le.lc['time'][::30], sim_le.lc['mag'][::30])

# %%
sim_le = SimulateLEInfPlane.CalculateLE(file_name='/pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml', 
                                ids=1, args=[False, False])
surface_val = sim_le.run()
plt.imshow(-2.5*np.log10(surface_val)-48.6, origin='lower', cmap='Greys_r')
plt.colorbar()
# Out:
# [False, False] /pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml 1
# {'Flmax': 1e+16, 'angles': [0, 360], 'ct': 640, 'd': 52000, 'dt0': 0, 'dz0': 0.06, 'plane_coefficients': [0.1, -0.5, 1, 120], 'wave': 0.567, 'loc_to_fits': '4026_15_v2/plane', 'composition': 'both'}
# /pscratch/sd/t/taceroc/LE_inj
# True
# TIME LE elliposid in days 656.8679000000047
# TIME of the SN LC respect to peak -16.867900000004738
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# mean of rho 37.592570724836364
# half_obs_thickness given by dust 0.0046855408176023
# carb values
# silicate values
# FLUX AFTER SURFACE 1.1901745819697693e-38
# size arcsec 91.0 91.0
# size img pixels 455 455
# OBS TIME 640.0
# True
# TIME LE elliposid in days 624.0312000000049
# TIME of the SN LC respect to peak 15.968799999995097
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 5.671489571383294e-16
# mean of rho 36.63798872512301
# half_obs_thickness given by dust 0.0045672201226314366
# carb values
# silicate values
# FLUX AFTER SURFACE 3.186908737624723e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 605.0108000000037
# TIME of the SN LC respect to peak 34.989199999996345
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 6.116837363414515e-16
# mean of rho 36.07364536398615
# half_obs_thickness given by dust 0.004497245796583918
# carb values
# silicate values
# FLUX AFTER SURFACE 3.4374408406348375e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 594.7243000000017
# TIME of the SN LC respect to peak 45.27569999999833
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 6.358218490763986e-16
# mean of rho 35.764774426679274
# half_obs_thickness given by dust 0.004458940753208854
# carb values
# silicate values
# FLUX AFTER SURFACE 3.57324762794867e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 584.3940000000002
# TIME of the SN LC respect to peak 55.60599999999977
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 6.449795327198281e-16
# mean of rho 35.45191150505194
# half_obs_thickness given by dust 0.004420135376703865
# carb values
# silicate values
# FLUX AFTER SURFACE 3.624875124395664e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 562.5959000000003
# TIME of the SN LC respect to peak 77.40409999999974
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 6.694127562418332e-16
# mean of rho 34.78260734639034
# half_obs_thickness given by dust 0.004337101891827031
# carb values
# silicate values
# FLUX AFTER SURFACE 3.7625488251905966e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 521.5740000000005
# TIME of the SN LC respect to peak 118.42599999999946
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 7.029788998199897e-16
# mean of rho 33.48718672624964
# half_obs_thickness given by dust 0.0041763261280751505
# carb values
# silicate values
# FLUX AFTER SURFACE 3.951915919278143e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 478.3228999999992
# TIME of the SN LC respect to peak 161.6771000000008
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 7.240944873261619e-16
# mean of rho 32.06533461142166
# half_obs_thickness given by dust 0.003999760890783068
# carb values
# silicate values
# FLUX AFTER SURFACE 4.07138430675018e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 443.86409999999876
# TIME of the SN LC respect to peak 196.13590000000116
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 7.331408270166057e-16
# mean of rho 30.886161589160615
# half_obs_thickness given by dust 0.003853256655549333
# carb values
# silicate values
# FLUX AFTER SURFACE 4.122865434798358e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 384.6546999999991
# TIME of the SN LC respect to peak 255.34530000000086
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b -0.5
# FLUX INTEGRAL IN TIME 7.412385256498134e-16
# mean of rho 28.748297972637165
# half_obs_thickness given by dust 0.0035874769017777792
# carb values
# silicate values
# FLUX AFTER SURFACE 4.169473891771724e-30
# Before angle clipping
# Len of z values
# 0
# Total shape
# (1, 2, 9000)
# FLUX 3.766740078710321e-30
# mean surface 24.752111932934188
# [-16.867900000004738, 15.968799999995097, 34.989199999996345, 45.27569999999833, 55.60599999999977, 77.40409999999974, 118.42599999999946, 161.6771000000008, 196.13590000000116, 255.34530000000086]
# [656.8679000000047, 624.0312000000049, 605.0108000000037, 594.7243000000017, 584.3940000000002, 562.5959000000003, 521.5740000000005, 478.3228999999992, 443.86409999999876, 384.6546999999991]
# (9000,)
# ANGLES
# 0 360
# 36.461939254142095 -36.80390411783195
# 37.48780669219045 -35.77812968832793
# (455, 455)
# (455, 455) (455, 455) nan nan

# %%
sim_le = SimulateLEInfPlane.CalculateLE(file_name='/pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml', 
                                ids=2, args=[False, False])
surface_val = sim_le.run()
plt.imshow(-2.5*np.log10(surface_val)-48.6, origin='lower', cmap='Greys_r')
plt.colorbar()
# Out:
# [False, False] /pscratch/sd/t/taceroc/LE_inj/params_le_for_4026_15_2022_y.yml 2
# {'Flmax': 1e+16, 'angles': [0, 360], 'ct': 640, 'd': 52000, 'dt0': 0, 'dz0': 0.06, 'plane_coefficients': [0, 0, 1, 120], 'wave': 0.567, 'loc_to_fits': '4026_15_v2/plane', 'composition': 'both'}
# /pscratch/sd/t/taceroc/LE_inj
# True
# TIME LE elliposid in days 656.8679000000047
# TIME of the SN LC respect to peak -16.867900000004738
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# mean of rho 37.575941362184594
# half_obs_thickness given by dust 0.004686218799740174
# carb values
# silicate values
# FLUX AFTER SURFACE 1.1901653198111636e-38
# size arcsec 91.0 91.0
# size img pixels 455 455
# OBS TIME 640.0
# True
# TIME LE elliposid in days 642.0013000000034
# TIME of the SN LC respect to peak -2.0013000000035395
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 2.0870947271746074e-16
# mean of rho 37.14732370673549
# half_obs_thickness given by dust 0.004633005005538011
# carb values
# silicate values
# FLUX AFTER SURFACE 1.1726744481761722e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 636.0540000000037
# TIME of the SN LC respect to peak 3.9459999999962743
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 3.843574219610491e-16
# mean of rho 36.97447878730019
# half_obs_thickness given by dust 0.004611543607316309
# carb values
# silicate values
# FLUX AFTER SURFACE 2.159642069943132e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 630.0740000000005
# TIME of the SN LC respect to peak 9.925999999999474
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 5.124032473916551e-16
# mean of rho 36.7998722576525
# half_obs_thickness given by dust 0.004589862125034552
# carb values
# silicate values
# FLUX AFTER SURFACE 2.879185513098425e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 624.0312000000049
# TIME of the SN LC respect to peak 15.968799999995097
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 5.671489571383294e-16
# mean of rho 36.62259388655853
# half_obs_thickness given by dust 0.004567847486726299
# carb values
# silicate values
# FLUX AFTER SURFACE 3.186884319063471e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 616.0561000000015
# TIME of the SN LC respect to peak 23.943899999998393
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 5.843897625397397e-16
# mean of rho 36.38731681569884
# half_obs_thickness given by dust 0.004538628358052027
# carb values
# silicate values
# FLUX AFTER SURFACE 3.2838762945156776e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 605.0108000000037
# TIME of the SN LC respect to peak 34.989199999996345
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.116837363414515e-16
# mean of rho 36.05895095667916
# half_obs_thickness given by dust 0.004497844445814733
# carb values
# silicate values
# FLUX AFTER SURFACE 3.4374147568227485e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 600.0020000000003
# TIME of the SN LC respect to peak 39.99799999999959
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.274512547488034e-16
# mean of rho 35.90906312775616
# half_obs_thickness given by dust 0.0044792264168457396
# carb values
# silicate values
# FLUX AFTER SURFACE 3.526098458497417e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 594.7243000000017
# TIME of the SN LC respect to peak 45.27569999999833
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.358218490763986e-16
# mean of rho 35.75045426634921
# half_obs_thickness given by dust 0.004459524061245355
# carb values
# silicate values
# FLUX AFTER SURFACE 3.573220661655559e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 589.5814000000026
# TIME of the SN LC respect to peak 50.41859999999724
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.409050049395334e-16
# mean of rho 35.5952222596036
# half_obs_thickness given by dust 0.004440240126435625
# carb values
# silicate values
# FLUX AFTER SURFACE 3.6018675964984955e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 584.3940000000002
# TIME of the SN LC respect to peak 55.60599999999977
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.449795327198281e-16
# mean of rho 35.43796393053855
# half_obs_thickness given by dust 0.004420703412704805
# carb values
# silicate values
# FLUX AFTER SURFACE 3.624847922999559e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 571.6240000000034
# TIME of the SN LC respect to peak 68.37599999999657
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.593641993498957e-16
# mean of rho 35.04785384003389
# half_obs_thickness given by dust 0.00437223420839956
# carb values
# silicate values
# FLUX AFTER SURFACE 3.705896522997806e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 562.5959000000003
# TIME of the SN LC respect to peak 77.40409999999974
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.694127562418332e-16
# mean of rho 34.769435136109095
# half_obs_thickness given by dust 0.004337638149873868
# carb values
# silicate values
# FLUX AFTER SURFACE 3.762520942036941e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 547.3740000000034
# TIME of the SN LC respect to peak 92.62599999999655
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 6.840236746816735e-16
# mean of rho 34.294927542643784
# half_obs_thickness given by dust 0.00427866877204649
# carb values
# silicate values
# FLUX AFTER SURFACE 3.8448975075756385e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 521.5740000000005
# TIME of the SN LC respect to peak 118.42599999999946
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.029788998199897e-16
# mean of rho 33.4754329298845
# half_obs_thickness given by dust 0.004176804267905176
# carb values
# silicate values
# FLUX AFTER SURFACE 3.9518873795698554e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 501.80400000000367
# TIME of the SN LC respect to peak 138.19599999999627
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.14599386402952e-16
# mean of rho 32.833735552295494
# half_obs_thickness given by dust 0.00409702123680243
# carb values
# silicate values
# FLUX AFTER SURFACE 4.017558242376662e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 478.3228999999992
# TIME of the SN LC respect to peak 161.6771000000008
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.240944873261619e-16
# mean of rho 32.05501671928607
# half_obs_thickness given by dust 0.004000180219690203
# carb values
# silicate values
# FLUX AFTER SURFACE 4.0713557972260215e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 460.6768999999985
# TIME of the SN LC respect to peak 179.3231000000014
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.292549242698884e-16
# mean of rho 31.457213472373546
# half_obs_thickness given by dust 0.003925821764860457
# carb values
# silicate values
# FLUX AFTER SURFACE 4.100685486390733e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 443.86409999999876
# TIME of the SN LC respect to peak 196.13590000000116
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.331408270166057e-16
# mean of rho 30.876942142812602
# half_obs_thickness given by dust 0.003853631015404064
# carb values
# silicate values
# FLUX AFTER SURFACE 4.122837351563939e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 414.95829999999836
# TIME of the SN LC respect to peak 225.0417000000016
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.38089956191743e-16
# mean of rho 29.85310892958218
# half_obs_thickness given by dust 0.003726226776930838
# carb values
# silicate values
# FLUX AFTER SURFACE 4.151189982704547e-30
# Before angle clipping
# Len of z values
# 0
# True
# TIME LE elliposid in days 384.6546999999991
# TIME of the SN LC respect to peak 255.34530000000086
# There are (1000,) intersections points in x
# There are (1000,) intersections points in y
# There are (1000,) intersections points in z
# Intersections
# (1000,)
# b 0
# FLUX INTEGRAL IN TIME 7.412385256498134e-16
# mean of rho 28.740866687111744
# half_obs_thickness given by dust 0.003587778106344488
# carb values
# silicate values
# FLUX AFTER SURFACE 4.169447014080799e-30
# Before angle clipping
# Len of z values
# 0
# Total shape
# (1, 2, 20000)
# FLUX 3.51719941338968e-30
# mean surface 24.857364937422794
# [-16.867900000004738, -2.0013000000035395, 3.9459999999962743, 9.925999999999474, 15.968799999995097, 23.943899999998393, 34.989199999996345, 39.99799999999959, 45.27569999999833, 50.41859999999724, 55.60599999999977, 68.37599999999657, 77.40409999999974, 92.62599999999655, 118.42599999999946, 138.19599999999627, 161.6771000000008, 179.3231000000014, 196.13590000000116, 225.0417000000016, 255.34530000000086]
# [656.8679000000047, 642.0013000000034, 636.0540000000037, 630.0740000000005, 624.0312000000049, 616.0561000000015, 605.0108000000037, 600.0020000000003, 594.7243000000017, 589.5814000000026, 584.3940000000002, 571.6240000000034, 562.5959000000003, 547.3740000000034, 521.5740000000005, 501.80400000000367, 478.3228999999992, 460.6768999999985, 443.86409999999876, 414.95829999999836, 384.6546999999991]
# (20000,)
# ANGLES
# 0 360
# 37.14732370673548 -37.147140025012014
# 37.14727778627623 -37.14727778627623
# (455, 455)
# (455, 455) (455, 455) nan nan

# %%
# import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from typing import Tuple, Iterable
import chart_studio.plotly as py
import plotly.express as px

# %%
x = np.linspace(-13, 13, 200)
y = np.linspace(-13, 13, 200)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2

# xP, yP = np.meshgrid(values, values)
d = -20
normal = (3.9, 0.3, 1)
zP = (-normal[0] * X - normal[1] * Y - d) * 1. / normal[2]

# d = -23
# normal = (0.9,1.3, 1)
# zP2 = (-normal[0] * X - normal[1] * Y - d) * 1. / normal[2]

surface = go.Surface(x=x, y=y, z=Z, colorscale="Greys", opacity = 0.5)
data = [surface]

layout = go.Layout(
    title='Parametric Plot',
    scene=dict(
        xaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        yaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        ),
        zaxis=dict(
            gridcolor='rgb(255, 255, 255)',
            zerolinecolor='rgb(255, 255, 255)',
            showbackground=True,
            backgroundcolor='rgb(230, 230,230)'
        )
    )
)
fig = make_subplots(rows=1, cols=1, specs=[[{'type': 'surface'}]])
# fig = go.Figure(data=data, layout=layout)
# surface = go.Surface(x=x, y=y, z=z, colorscale=colorScaleName, showscale=False)
fig.add_trace(surface, row=1, col=1)
surfaceP = go.Surface(x=x, y=y, z=zP, colorscale="Viridis_r", showscale=False, opacity = 1)
fig.add_trace(surfaceP, row=1, col=1)
# surfaceP = go.Surface(x=x, y=y, z=zP2, colorscale="Greys", showscale=False,opacity=0.5)
# fig.add_trace(surfaceP, row=1, col=1)

# x = np.linspace(-8, 8, 200)
# y = np.linspace(-8, 8, 200)
X, Y = np.meshgrid(x, y)
Z = X**2 + Y**2 - 80
surface = go.Surface(x=x, y=y, z=Z, colorscale="Greys", opacity = 0.5)
fig.add_trace(surface, row=1, col=1)
fig.add_trace(go.Scatter3d(x=[0],y=[0], z=[50]), row=1, col=1)
fig.update_layout(
    autosize=False,  # Set to False to enable manual size control
    width=900,
    height=700,
)
# plotPlane(fig, (3, 2, -4), 1, values, "Greys")

fig.show()
