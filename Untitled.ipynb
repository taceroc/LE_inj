# %%
import glob

# %%
subfolder = 'plane8_0-60arc'
# subfolder_2  = 'plane12_0-60arc'

# %%
#500, 650
list_fits = [sorted(glob.glob(f"fits/4026_15_v2/{subfolder}/*52000.0pc.fits"))]#, sorted(glob.glob(f"fits/4026_15_v2/{subfolder_2}/*52000.0pc.fits"))]

# %%
list_fits
# Out:
# [['fits/4026_15_v2/plane8_0-60arc/surface_valueslc2_InfPlane_dt0_loop_ct400_loc[0, 0, 1, -26.09248]_dz0.06_w567_angle[0, 60]_sourced52000.0pc.fits',
#   'fits/4026_15_v2/plane8_0-60arc/surface_valueslc2_InfPlane_dt0_loop_ct450_loc[0, 0, 1, -26.09248]_dz0.06_w567_angle[0, 60]_sourced52000.0pc.fits',
#   'fits/4026_15_v2/plane8_0-60arc/surface_valueslc2_InfPlane_dt0_loop_ct500_loc[0, 0, 1, -26.09248]_dz0.06_w567_angle[0, 60]_sourced52000.0pc.fits',
#   'fits/4026_15_v2/plane8_0-60arc/surface_valueslc2_InfPlane_dt0_loop_ct550_loc[0, 0, 1, -26.09248]_dz0.06_w567_angle[0, 60]_sourced52000.0pc.fits',
#   'fits/4026_15_v2/plane8_0-60arc/surface_valueslc2_InfPlane_dt0_loop_ct700_loc[0, 0, 1, -26.09248]_dz0.06_w567_angle[0, 60]_sourced52000.0pc.fits']]

# %%
list_metadata = []
for lls in list_fits[0]: 
    edits = lls.replace(lls.split('surface')[0], 'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/')
    edits = edits.replace('surface_values', 'meta_info')
    edits = edits.replace('fits', 'pkl')
    list_metadata.append(edits)

# %%
list_metadata
# Out:
# ['lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct400_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct450_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct500_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct550_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct640_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct650_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct690_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl',
#  'lightecho_modeling_oop/OOP/results/LC_infplane_test_multi/arrays/meta_infolc2_InfPlane_dt0_loop_ct700_loc[0, 0, 1, -391.38719999999995]_dz0.06_w567_angle[0, 360]_sourced52000.0pc.pkl']

# %%
ids_to_use_time_fits = [0,1]
list_fits = [1]

# %%
    # print(llix)
for llfits, ids_to_use_time_fitsidx in zip(list_fits, ids_to_use_time_fits):
    print(llfits, ids_to_use_time_fitsidx)
# Out:
# 1 0

# %%
sorted(glob.glob(f"fits/4026_15_v2/{'none'}/*52000.0pc.fits"))
# Out:
# []
